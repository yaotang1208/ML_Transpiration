# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import warnings

from datetime import datetime, date,timedelta
from matplotlib import gridspec
from matplotlib import cm

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df_SF = pd.read_pickle('df_SF.pkl')

# %%
df_SF.head()
# Out:
#             TIMESTAMP  DOY  SV_IN_1A  SV_OUT_1A  SV_MEAN_1A  SV_IN_1B  \
# 0 2015-01-01 00:00:00    1       NaN        NaN         NaN       NaN
# 1 2015-01-01 00:15:00    1       NaN        NaN         NaN       NaN
# 2 2015-01-01 00:30:00    1       NaN        NaN         NaN       NaN
# 3 2015-01-01 00:45:00    1       NaN        NaN         NaN       NaN
# 4 2015-01-01 01:00:00    1       NaN        NaN         NaN       NaN
#
#    SV_OUT_1B  SV_MEAN_1B  SV_IN_2A  SV_OUT_2A  ...  SV_MEAN_6A  SV_IN_7A  \
# 0        NaN         NaN       NaN        NaN  ...         NaN       NaN
# 1        NaN         NaN       NaN        NaN  ...         NaN       NaN
# 2        NaN         NaN       NaN        NaN  ...         NaN       NaN
# 3        NaN         NaN       NaN        NaN  ...         NaN       NaN
# 4        NaN         NaN       NaN        NaN  ...         NaN       NaN
#
#    SV_OUT_7A  SV_MEAN_7A  SV_IN_8A  SV_OUT_8A  SV_MEAN_8A  SV_IN_9A  \
# ...

# %%
# plt.figure(figsize=(10,4))
df_SF.plot(x='TIMESTAMP',y=['SV_IN_1A','SV_OUT_1A','SV_MEAN_1A'],figsize=(10,6),alpha=0.7)

# %%
time_start = datetime(2015,10,9,0,0,0)
time_end = datetime(2015,11,1,0,0,0)
df_SF.plot(x='TIMESTAMP',y=['SV_OUT_1A'],figsize=(10,6),alpha=0.7)
plt.xlim(time_start,time_end)
# Out:
# (735880.0, 735903.0)

# %%
df_SF.plot(x='TIMESTAMP',y=['SV_OUT_1A','SV_IN_1A'],figsize=(10,6),alpha=0.7)

# %%
# plt.figure(figsize=(10,4))
df_SF.plot(x='TIMESTAMP',y=['SV_IN_1B','SV_OUT_1B','SV_MEAN_1B'],figsize=(10,6),alpha=0.7)

# %%
df_SF.plot(x='TIMESTAMP',y=['SV_OUT_1B','SV_IN_1B'],figsize=(10,6),alpha=0.7)

# %%
# plt.figure(figsize=(10,4))
df_SF.plot(x='TIMESTAMP',y=['SV_IN_2A','SV_OUT_2A','SV_MEAN_2A'],figsize=(10,6),alpha=0.7)

# %%
# plt.figure(figsize=(10,4))
df_SF.plot(x='TIMESTAMP',y=['SV_OUT_2A','SV_IN_2A'],figsize=(10,6),alpha=0.7)

# %%
# plt.figure(figsize=(10,4))
df_SF.plot(x='TIMESTAMP',y=['SV_IN_2B','SV_OUT_2B','SV_MEAN_2B'],figsize=(10,6),alpha=0.7)

# %%
df_SF.plot(x='TIMESTAMP',y=['SV_OUT_2B','SV_IN_2B'],figsize=(10,6),alpha=0.7)

# %%
# plt.figure(figsize=(10,4))
df_SF.plot(x='TIMESTAMP',y=['SV_IN_3A','SV_OUT_3A','SV_MEAN_3A'],figsize=(10,6),alpha=0.7)

# %%
df_SF.plot(x='TIMESTAMP',y=['SV_OUT_3A','SV_IN_3A'],figsize=(10,6),alpha=0.7)

# %%
# plt.figure(figsize=(10,4))
df_SF.plot(x='TIMESTAMP',y=['SV_IN_3B','SV_OUT_3B','SV_MEAN_3B'],figsize=(10,6),alpha=0.7)

# %%
df_SF.plot(x='TIMESTAMP',y=['SV_OUT_3B','SV_IN_3B'],figsize=(10,6),alpha=0.7)

# %%
# plt.figure(figsize=(10,4))
df_SF.plot(x='TIMESTAMP',y=['SV_IN_4A','SV_OUT_4A','SV_MEAN_4A'],figsize=(10,6),alpha=0.7)

# %%
df_SF.plot(x='TIMESTAMP',y=['SV_OUT_4A','SV_IN_4A'],figsize=(10,6),alpha=0.7)

# %%
# plt.figure(figsize=(10,4))
df_SF.plot(x='TIMESTAMP',y=['SV_IN_5A','SV_OUT_5A','SV_MEAN_5A'],figsize=(10,6),alpha=0.7)

# %%
df_SF.plot(x='TIMESTAMP',y=['SV_OUT_5A','SV_IN_5A'],figsize=(10,6),alpha=0.7)

# %%
# plt.figure(figsize=(10,4))
df_SF.plot(x='TIMESTAMP',y=['SV_IN_5B','SV_OUT_5B','SV_MEAN_5B'],figsize=(10,6),alpha=0.7)

# %%
df_SF.plot(x='TIMESTAMP',y=['SV_OUT_5B','SV_IN_5B'],figsize=(10,6),alpha=0.7)

# %%
# plt.figure(figsize=(10,4))
df_SF.plot(x='TIMESTAMP',y=['SV_IN_6A','SV_OUT_6A','SV_MEAN_6A'],figsize=(10,6),alpha=0.7)

# %%
df_SF.plot(x='TIMESTAMP',y=['SV_OUT_6A','SV_IN_6A'],figsize=(10,6),alpha=0.7)

# %%
# plt.figure(figsize=(10,4))
df_SF.plot(x='TIMESTAMP',y=['SV_IN_7A','SV_OUT_7A','SV_MEAN_7A'],figsize=(10,6),alpha=0.7)

# %%
df_SF.plot(x='TIMESTAMP',y=['SV_OUT_7A','SV_IN_7A'],figsize=(10,6),alpha=0.7)

# %%
# plt.figure(figsize=(10,4))
df_SF.plot(x='TIMESTAMP',y=['SV_IN_8A','SV_OUT_8A','SV_MEAN_8A'],figsize=(10,6),alpha=0.7)

# %%
df_SF.plot(x='TIMESTAMP',y=['SV_OUT_8A','SV_IN_8A'],figsize=(10,6),alpha=0.7)

# %%
# plt.figure(figsize=(10,4))
df_SF.plot(x='TIMESTAMP',y=['SV_IN_9A','SV_OUT_9A','SV_MEAN_9A'],figsize=(10,6),alpha=0.7)

# %%
df_SF.plot(x='TIMESTAMP',y=['SV_OUT_9A','SV_IN_9A'],figsize=(10,6),alpha=0.7)

# %%
# diurnal variation of sap flow
