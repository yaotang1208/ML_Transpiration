# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import warnings

from datetime import datetime, date,timedelta
from matplotlib import gridspec
from matplotlib import cm

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
sns.set(style="whitegrid")

# %%
df_SF_daily = pd.read_pickle('df_SF_daily.pkl')
df_met_daily = pd.read_pickle('df_met_daily.pkl')

# %%
df_SF_daily.head()
# Out:
#          DATE  DOY  SV_IN_1A  SV_OUT_1A  SV_MEAN_1A  SV_IN_1B  SV_OUT_1B  \
# 0  2015-01-01    1       NaN        NaN         NaN       NaN        NaN
# 1  2015-01-02    2       NaN        NaN         NaN       NaN        NaN
# 2  2015-01-03    3       NaN        NaN         NaN       NaN        NaN
# 3  2015-01-04    4       NaN        NaN         NaN       NaN        NaN
# 4  2015-01-05    5       NaN        NaN         NaN       NaN        NaN
#
#    SV_MEAN_1B  SV_IN_2A  SV_OUT_2A  ...  SV_MEAN_6A  SV_IN_7A  SV_OUT_7A  \
# 0         NaN       NaN        NaN  ...         NaN       NaN        NaN
# 1         NaN       NaN        NaN  ...         NaN       NaN        NaN
# 2         NaN       NaN        NaN  ...         NaN       NaN        NaN
# 3         NaN       NaN        NaN  ...         NaN       NaN        NaN
# 4         NaN       NaN        NaN  ...         NaN       NaN        NaN
#
#    SV_MEAN_7A  SV_IN_8A  SV_OUT_8A  SV_MEAN_8A  SV_IN_9A  SV_OUT_9A  \
# ...

# %%
df_met_daily.head()
# Out:
#          DATE  TIMESTAMP_START  TIMESTAMP_END         G  SWC_1  SWC_2  SWC_3  \
# 0  2012-01-01     2.012010e+11   2.012010e+11  0.632000    NaN    NaN    NaN
# 1  2012-01-02     2.012010e+11   2.012010e+11 -1.848444    NaN    NaN    NaN
# 2  2012-01-03     2.012010e+11   2.012010e+11  0.182951    NaN    NaN    NaN
# 3  2012-01-04     2.012010e+11   2.012010e+11 -1.401215    NaN    NaN    NaN
# 4  2012-01-05     2.012011e+11   2.012011e+11 -0.870958    NaN    NaN    NaN
#
#    SWC_4  SWC_5  SWC_6  ...       CO2_3       CO2_4       CO2_5       CO2_6  \
# 0    NaN    NaN    NaN  ...  386.396875  391.075000  399.081818  440.045455
# 1    NaN    NaN    NaN  ...  409.279167  417.504167  427.652083  450.410417
# 2    NaN    NaN    NaN  ...  392.363889  394.869444  401.347222  427.755556
# 3    NaN    NaN    NaN  ...  392.895833  396.629167  403.016667  420.154167
# 4    NaN    NaN    NaN  ...  399.050000  403.935714  412.473810  424.359524
#
# ...

# %%
sns.lineplot(x = 'DATE',y='P_1',data = df_met_daily)

# %%
# sns.barplot(x = 'DATE',y=['P_1'],data = df_met_daily)

# %%
# # plot sap flow, precipitation, and soil moisture
# f, axes = plt.subplots(3, 1, figsize=(12, 8), sharex=True)
# # ax = list(axes.ravel())

# # idx = 0
# sns.lineplot(x ='DATE', y='P_1', data = df_met_daily, ax = axes[0])

# # idx = 1
# sns.lineplot(x = 'DATE',y=['SV_MEAN_1A','SV_MEAN_2A','SV_MEAN_3A','SV_MEAN_4A',
#                    'SV_MEAN_5A','SV_MEAN_6A','SV_MEAN_7A','SV_MEAN_8A','SV_MEAN_9A'],
#                 data = df_SF_daily,ax = axes[1])

# # idx = 2
# sns.lineplot(x = 'DATE',y=['SWC_1','SWC_2','SWC_3','SWC_4','SWC_5','SWC_6'],
#                       data = df_met_daily, ax = axes[2])

# %%
sns.lineplot(x ='DATE', y='P_1', data = df_met_daily)

# %%
# plot sap flow, precipitation, and soil moisture
f, axes = plt.subplots(3, 1, figsize=(12, 8), sharex=True)
# ax = list(axes.ravel())

idx = 0
df_met_daily.plot(x ='DATE', y=['P_1','P_2'], ax = axes[idx],style = '.')

idx = 1
df_SF_daily.plot(x = 'DATE',y=['SV_MEAN_1A','SV_MEAN_2A','SV_MEAN_3A','SV_MEAN_4A',
                   'SV_MEAN_5A','SV_MEAN_6A','SV_MEAN_7A','SV_MEAN_8A','SV_MEAN_9A'],style = '.',
                ax = axes[idx])

idx = 2
df_met_daily.plot(x = 'DATE',y=['SWC_1','SWC_2','SWC_3','SWC_4','SWC_5','SWC_6'],style = '.',
                      ax = axes[idx])

# %%
time_start = pd.Timestamp('2015-01-01')
time_end = pd.Timestamp('2016-12-31')

# %%
# plot sap flow, precipitation, and soil moisture
f, axes = plt.subplots(3, 1, figsize=(12, 8), sharex=True)
# ax = list(axes.ravel())

idx = 0
df_met_daily.plot(x ='DATE', y=['P_1','P_2'], ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylim(0,50)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 1
df_SF_daily.plot(x = 'DATE',y=['SV_MEAN_1A','SV_MEAN_2A','SV_MEAN_3A','SV_MEAN_4A',
                   'SV_MEAN_5A','SV_MEAN_6A','SV_MEAN_7A','SV_MEAN_8A','SV_MEAN_9A'],style = '.',
                ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 2
df_met_daily.plot(x = 'DATE',y=['SWC_1','SWC_2','SWC_3','SWC_4','SWC_5','SWC_6'],style = '.',
                      ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
time_start = pd.Timestamp('2015-01-01')
time_end = pd.Timestamp('2016-12-31')

# %%
# plot sap flow, precipitation, and soil moisture
f, axes = plt.subplots(3, 1, figsize=(12, 8), sharex=True)
# ax = list(axes.ravel())

idx = 0
df_met_daily.plot(x ='DATE', y=['P_1','P_2'], ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylim(0,50)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 1
df_SF_daily.plot(x = 'DATE',y=['SV_MEAN_1A','SV_MEAN_2A','SV_MEAN_3A','SV_MEAN_4A',
                   'SV_MEAN_5A','SV_MEAN_6A','SV_MEAN_7A','SV_MEAN_8A','SV_MEAN_9A'],style = '.',
                ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 2
df_met_daily.plot(x = 'DATE',y=['SWC_1','SWC_2','SWC_3','SWC_4','SWC_5','SWC_6'],style = '.',
                      ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
# plot sap flow, precipitation, and soil moisture
f, axes = plt.subplots(3, 1, figsize=(12, 8), sharex=True)
# ax = list(axes.ravel())

idx = 0
df_met_daily.plot(x ='DATE', y=['P_1','P_2'], ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylim(0,50)
axes[idx].set_ylabel('PREC (mm/day)')
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 1
df_SF_daily.plot(x = 'DATE',y=['SV_MEAN_1A','SV_MEAN_2A','SV_MEAN_3A','SV_MEAN_4A',
                   'SV_MEAN_5A'],style = '.',
                ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))
axes[idx].set_ylabel('Sap Velocity (cm/h)')

idx = 2
df_met_daily.plot(x = 'DATE',y=['SWC_1','SWC_2','SWC_3','SWC_4','SWC_5','SWC_6'],style = '.',
                      ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))
axes[idx].set_ylabel('SWC (m3/m3)')
# Out:
# Text(0, 0.5, 'SWC (m3/m3)')

# %%
# plot sap flow, precipitation, and soil moisture
f, axes = plt.subplots(3, 1, figsize=(12, 8), sharex=True)
# ax = list(axes.ravel())

idx = 0
df_met_daily.plot(x ='DATE', y=['P_1','P_2'], ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylim(0,50)
axes[idx].set_ylabel('PREC (mm/day)')
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 1
df_SF_daily.plot(x = 'DATE',y=['SV_OUT_1A','SV_OUT_2A','SV_OUT_3A',
                   'SV_OUT_5A'],style = '.',
                ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylabel('Sap Velocity ($cm h^{-1}$)')
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 2
df_met_daily.plot(x = 'DATE',y=['SWC_1','SWC_2','SWC_3','SWC_4','SWC_5','SWC_6'],style = '.',
                      ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))
axes[idx].set_ylabel('SWC (m3/m3)')
# Out:
# Text(0, 0.5, 'SWC (m3/m3)')

# %%
# plot sap flow, precipitation, and soil moisture
f, axes = plt.subplots(3, 1, figsize=(12, 8), sharex=True)
# ax = list(axes.ravel())

idx = 0
df_met_daily.plot(x ='DATE', y=['P_1','P_2'], ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylim(0,50)
axes[idx].set_ylabel('PREC (mm/day)')
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 1
df_SF_daily.plot(x = 'DATE',y=['SV_OUT_1A','SV_OUT_2A','SV_OUT_3A',
                   'SV_OUT_5A'],style = '.',
                ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylabel('Sap Velocity ($cm h^{-1}$)')
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 2
df_met_daily.plot(x = 'DATE',y=['SWC_1','SWC_2','SWC_3','SWC_4','SWC_5','SWC_6'],style = '.',
                      ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))
axes[idx].set_ylabel('SWC (m3/m3)')
# Out:
# Text(0, 0.5, 'SWC (m3/m3)')

# %%
df_SF_daily['SV_OUT'] = df_SF_daily[['SV_OUT_1A','SV_OUT_2A','SV_OUT_3A','SV_OUT_5A']].astype(float).mean(axis =1)
df_met_daily['SWC'] = df_met_daily[['SWC_1','SWC_2','SWC_3','SWC_4','SWC_5','SWC_6']].astype(float).mean(axis =1)
df_met_daily['TS'] = df_met_daily[['TS_1','TS_2','TS_3','TS_4','TS_5']].astype(float).mean(axis =1)
df_met_daily['TA'] = df_met_daily[['TA_1','TA_2','TA_3','TA_4','TA_5','TA_6']].astype(float).mean(axis =1)

# %%
# print(list(df_SF_daily['SV_OUT']))

# %%
# plot sap flow, precipitation, and soil moisture
f, axes = plt.subplots(3, 1, figsize=(12, 8), sharex=True)
# ax = list(axes.ravel())

idx = 0
df_met_daily.plot(x ='DATE', y=['P_1','P_2'], ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylim(0,50)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 1
df_SF_daily.plot(x = 'DATE',y=['SV_OUT'],style = '.',
                ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 2
df_met_daily.plot(x = 'DATE',y=['SWC'],style = '.',
                      ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
# time_start = pd.Timestamp('2015-07-01')
# time_end = pd.Timestamp('2016-12-31')
df_SF_daily['DATE'] = pd.to_datetime(df_SF_daily['DATE'])
df_met_daily['DATE'] = pd.to_datetime(df_met_daily['DATE'])
mask_sf = (df_SF_daily['DATE'] >= time_start) & (df_SF_daily['DATE'] < time_end)
mask_met = (df_met_daily['DATE'] >= time_start) & (df_met_daily['DATE'] < time_end)

# %%
# print(list(mask_sf))

# %%
plt.scatter(df_SF_daily['SV_OUT'][mask_sf],df_met_daily['SWC'][mask_met])

# %%
from scipy import stats
# fig, ax = plt.figure(figsize = (4,4))
g = sns.JointGrid(df_met_daily['SWC'][mask_met],df_SF_daily['SV_OUT'][mask_sf],height = 5, ratio=100)
g.plot_joint(sns.regplot)
# g.annotate(stats.pearsonr)
rsquare = lambda a, b: stats.pearsonr(a, b)[0]
# g.annotate(rsquare, template="{stat}: {val:.2f}",stat="$R$", loc="upper left")
# g.ax_marg_x.set_axis_off()
# g.ax_marg_y.set_axis_off()
plt.xlabel('Daily SWC ($m^3 m^{-3}$)')
plt.ylabel('Daily SV ($cm h^{-1}$)')
plt.savefig('SVSWC.png', dpi=300)

# %%
# fig, ax = plt.figure(figsize = (4,4))
g = sns.JointGrid(df_met_daily['P_1'][mask_met],df_SF_daily['SV_OUT'][mask_sf],height = 5, ratio=100)
g.plot_joint(sns.regplot)
# g.annotate(stats.pearsonr)
# rsquare = lambda a, b: stats.pearsonr(a, b)[0]
# g.annotate(rsquare, template="{stat}: {val:.2f}",stat="$R$", loc="upper left")
# g.ax_marg_x.set_axis_off()
# g.ax_marg_y.set_axis_off()
plt.xlabel('Daily PREP ($mm day^{-1}$)')
plt.ylabel('Daily SV ($cm h^{-1}$)')
plt.savefig('SVPREP.png', dpi=300)

# %%
# fig, ax = plt.figure(figsize = (4,4))
g = sns.JointGrid(df_met_daily['NETRAD'][mask_met],df_SF_daily['SV_OUT'][mask_sf],height = 5, ratio=100)
g.plot_joint(sns.regplot)
# g.annotate(stats.pearsonr)
# rsquare = lambda a, b: stats.pearsonr(a, b)[0]
# g.annotate(rsquare, template="{stat}: {val:.2f}",stat="$R$", loc="upper left")
# g.ax_marg_x.set_axis_off()
# g.ax_marg_y.set_axis_off()
plt.xlabel('Daily NETRAD ($W m^{-2}$)')
plt.ylabel('Daily SV ($cm h^{-1}$)')
plt.savefig('SVRN.png', dpi=300)

# %%
sns.regplot(df_met_daily['SWC'][mask_met],df_SF_daily['SV_OUT'][mask_sf])
plt.axis('scaled')
# Out:
# (0.23895898448179798,
#  0.39174934885153534,
#  -0.7214543147611967,
#  9.80891841224048)

# %%
sns.regplot(df_SF_daily['SV_OUT'][mask_sf],df_met_daily['SWC'][mask_met],logx = True) # log x

# %%
# sns.regplot(np.log(df_SF_daily['SV_OUT'][mask_sf]),df_met_daily['SWC'][mask_met]) # log x

# %%
from scipy import stats

# %%
fig, ax = plt.subplots(figsize=(4,4))
sns.jointplot(df_met_daily['SWC'][mask_met],df_SF_daily['SV_OUT'][mask_sf],kind = 'reg')
cov,p_value = stats.spearmanr(df_met_daily['SWC'][mask_met],df_SF_daily['SV_OUT'][mask_sf],nan_policy = 'omit')
print(cov)
# Out:
# 0.19178899670858418

# %%
sns.jointplot(df_SF_daily['SV_OUT'][mask_sf],df_met_daily['SWC'][mask_met],kind = 'reg',logx = True)

# %%
sns.jointplot(df_SF_daily['SV_OUT'][mask_sf],df_met_daily['SWC'][mask_met],kind = 'kde')

# %%
sns.jointplot(df_met_daily['P_1'][mask_met],df_SF_daily['SV_OUT'][mask_sf],kind = 'reg')
cov,p_value = stats.spearmanr(df_met_daily['P_1'][mask_met],df_SF_daily['SV_OUT'][mask_sf],nan_policy = 'omit')
plt.text(10,8,"R = -0.33")
print(cov)
# Out:
# -0.33344982210071084

# %%
sns.jointplot(df_met_daily['P_1'][mask_met], df_met_daily['SWC'][mask_met],kind = 'reg')
cov,p_value = stats.spearmanr(df_met_daily['P_1'][mask_met], df_met_daily['SWC'][mask_met],nan_policy = 'omit')
plt.text(10,0.4,"R = 0.29")
print(cov)
# Out:
# 0.23434074401274227

# %%
# plot radiation with sap flow
# plot sap flow, precipitation, and soil moisture
f, axes = plt.subplots(3, 1, figsize=(12, 8), sharex=True)
# ax = list(axes.ravel())

idx = 0
df_met_daily.plot(x ='DATE', y=['P_1','P_2'], ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylim(0,50)
axes[idx].set_ylabel('PREC (mm/day)')
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 1
df_SF_daily.plot(x = 'DATE',y=['SV_OUT_1A','SV_OUT_2A','SV_OUT_3A',
                   'SV_OUT_5A'],style = '.',
                ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylabel('Sap Velocity (cm/h)')
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 2
df_met_daily.plot(x = 'DATE',y=['NETRAD'],style = '.',
                      ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))
axes[idx].set_ylabel('NETRAD (m3/m3)')
# Out:
# Text(0, 0.5, 'NETRAD (m3/m3)')

# %%
# plot radiation with sap flow
# plot sap flow, precipitation, and soil moisture
f, axes = plt.subplots(3, 1, figsize=(12, 8), sharex=True)
# ax = list(axes.ravel())

idx = 0
df_met_daily.plot(x ='DATE', y=['P_1','P_2'], ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylim(0,50)
axes[idx].set_ylabel('PREC (mm/day)')
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 1
df_SF_daily.plot(x = 'DATE',y=['SV_OUT'],style = '.',
                ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylabel('Sap Velocity (cm/h)')
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 2
df_met_daily.plot(x = 'DATE',y=['NETRAD'],style = '.',
                      ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))
axes[idx].set_ylabel('NETRAD (W m-2)')
# Out:
# Text(0, 0.5, 'NETRAD (W m-2)')

# %%
sns.jointplot(df_met_daily['NETRAD'][mask_met],df_SF_daily['SV_OUT'][mask_sf],kind = 'reg')
cov,p_value = stats.spearmanr(df_met_daily['NETRAD'][mask_met],df_SF_daily['SV_OUT'][mask_sf],nan_policy = 'omit')
plt.text(0,8,"R = 0.53")
print(cov)
# Out:
# 0.5289112969602556

# %%
# plot sap flow, precipitation, and soil moisture
f, axes = plt.subplots(3, 1, figsize=(12, 8), sharex=True)
# ax = list(axes.ravel())

idx = 0
df_met_daily.plot(x ='DATE', y=['P_1','P_2'], ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylim(0,50)
axes[idx].set_ylabel('PREC (mm/day)')
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 1
df_SF_daily.plot(x = 'DATE',y=['SV_OUT_1A','SV_OUT_2A','SV_OUT_3A',
                   'SV_OUT_5A'],style = '.',
                ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylabel('Sap Velocity (cm/h)')
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 2
df_met_daily.plot(x = 'DATE',y=['TA_1','TA_2','TA_3','TA_4','TA_5','TA_6'],style = '.',
                      ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))
axes[idx].set_ylabel('TA (DegC)')
# Out:
# Text(0, 0.5, 'TA (DegC)')

# %%
# plot sap flow, precipitation, and soil moisture
f, axes = plt.subplots(3, 1, figsize=(12, 8), sharex=True)
# ax = list(axes.ravel())

idx = 0
df_met_daily.plot(x ='DATE', y=['P_1','P_2'], ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylim(0,50)
axes[idx].set_ylabel('PREC (mm/day)')
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 1
df_SF_daily.plot(x = 'DATE',y=['SV_OUT'],style = '.',
                ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylabel('Sap Velocity (cm/h)')
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 2
df_met_daily.plot(x = 'DATE',y=['TA'],style = '.',
                      ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))
axes[idx].set_ylabel('TA (DegC)')
# Out:
# Text(0, 0.5, 'TA (DegC)')

# %%
sns.jointplot(df_met_daily['TA'][mask_met],df_SF_daily['SV_OUT'][mask_sf],kind = 'reg')
cov,p_value = stats.spearmanr(df_met_daily['TA'][mask_met],df_SF_daily['SV_OUT'][mask_sf],nan_policy = 'omit')
plt.text(24,8,"R = 0.40")
print(cov)
# Out:
# 0.43997609027536566

# %%
sns.jointplot(df_met_daily['TA'][mask_met],df_met_daily['NETRAD'][mask_met],kind = 'reg')
cov,p_value = stats.spearmanr(df_met_daily['TA'][mask_met],df_met_daily['NETRAD'][mask_met],nan_policy = 'omit')
plt.text(24,250,"R = 0.67")
print(cov)
# Out:
# 0.6749679904715823

# %%
# plot sap flow, precipitation, and soil moisture
f, axes = plt.subplots(3, 1, figsize=(12, 8), sharex=True)
# ax = list(axes.ravel())

idx = 0
df_met_daily.plot(x ='DATE', y=['P_1','P_2'], ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylim(0,50)
axes[idx].set_ylabel('PREC (mm/day)')
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 1
df_SF_daily.plot(x = 'DATE',y=['SV_OUT_1A','SV_OUT_2A','SV_OUT_3A',
                   'SV_OUT_5A'],style = '.',
                ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylabel('Sap Velocity (cm/h)')
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 2
df_met_daily.plot(x = 'DATE',y=['TS_1','TS_2','TS_3','TS_4','TS_5'],style = '.',
                      ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylim(24,30)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))
axes[idx].set_ylabel('TS (DegC)')
# Out:
# Text(0, 0.5, 'TS (DegC)')

# %%
# plot sap flow, precipitation, and soil moisture
f, axes = plt.subplots(3, 1, figsize=(12, 8), sharex=True)
# ax = list(axes.ravel())

idx = 0
df_met_daily.plot(x ='DATE', y=['P_1','P_2'], ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylim(0,50)
axes[idx].set_ylabel('PREC (mm/day)')
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 1
df_SF_daily.plot(x = 'DATE',y=['SV_OUT'],style = '.',
                ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylabel('Sap Velocity (cm/h)')
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 2
df_met_daily.plot(x = 'DATE',y=['TS'],style = '.',
                      ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylim(24,30)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))
axes[idx].set_ylabel('TS (DegC)')
# Out:
# Text(0, 0.5, 'TS (DegC)')

# %%
sns.jointplot(df_met_daily['TS'][mask_met],df_SF_daily['SV_OUT'][mask_sf],kind = 'reg')

# %%
sns.jointplot(df_met_daily['TS'][mask_met],df_met_daily['NETRAD'][mask_met],kind = 'reg')

# %%
# plot sap flow, precipitation, and soil moisture
f, axes = plt.subplots(3, 1, figsize=(12, 8), sharex=True)
# ax = list(axes.ravel())

idx = 0
df_SF_daily.plot(x = 'DATE',y=['SV_OUT'],style = '.',
                ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylabel('Sap Velocity (cm/h)')
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 1
df_met_daily.plot(x = 'DATE',y=['TS'],style = '.',
                      ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylim(24,30)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))
axes[idx].set_ylabel('TS (DegC)')

idx = 2
df_met_daily.plot(x = 'DATE',y=['G'],style = '.',
                      ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
# axes[idx].set_ylim(24,30)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))
axes[idx].set_ylabel('G (W m-2)')
# Out:
# Text(0, 0.5, 'G (W m-2)')

# %%
# plot sap flow, precipitation, and soil moisture
f, axes = plt.subplots(3, 1, figsize=(12, 8), sharex=True)
# ax = list(axes.ravel())

idx = 0
df_SF_daily.plot(x = 'DATE',y=['SV_OUT'],style = '.',
                ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylabel('Sap Velocity (cm/h)')
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))

idx = 1
df_met_daily.plot(x = 'DATE',y=['TA'],style = '.',
                      ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
axes[idx].set_ylim(22,32)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))
axes[idx].set_ylabel('TA (DegC)')

idx = 2
df_met_daily.plot(x = 'DATE',y=['RH_1'],style = '.',
                      ax = axes[idx])
axes[idx].set_xlim(time_start,time_end)
# axes[idx].set_ylim(24,30)
axes[idx].legend(loc='center left', bbox_to_anchor=(1, 0.5))
axes[idx].set_ylabel('RH (%)')
# Out:
# Text(0, 0.5, 'RH (%)')

# %%
sns.jointplot(df_met_daily['RH_1'][mask_met],df_SF_daily['SV_OUT'][mask_sf],kind = 'reg')

# %%
sns.jointplot(df_met_daily['RH_1'][mask_met],df_met_daily['TA'][mask_met],kind = 'reg')
