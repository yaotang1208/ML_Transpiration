# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import warnings

from datetime import datetime, date,timedelta
from matplotlib import gridspec
from matplotlib import cm

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df_SF = pd.read_pickle('df_SF.pkl')

# %%
df_SF.head()
# Out:
#             TIMESTAMP  DOY  SV_IN_1A  SV_OUT_1A  SV_MEAN_1A  SV_IN_1B  \
# 0 2015-01-01 00:00:00    1       NaN        NaN         NaN       NaN
# 1 2015-01-01 00:15:00    1       NaN        NaN         NaN       NaN
# 2 2015-01-01 00:30:00    1       NaN        NaN         NaN       NaN
# 3 2015-01-01 00:45:00    1       NaN        NaN         NaN       NaN
# 4 2015-01-01 01:00:00    1       NaN        NaN         NaN       NaN
#
#    SV_OUT_1B  SV_MEAN_1B  SV_IN_2A  SV_OUT_2A  ...  SV_MEAN_6A  SV_IN_7A  \
# 0        NaN         NaN       NaN        NaN  ...         NaN       NaN
# 1        NaN         NaN       NaN        NaN  ...         NaN       NaN
# 2        NaN         NaN       NaN        NaN  ...         NaN       NaN
# 3        NaN         NaN       NaN        NaN  ...         NaN       NaN
# 4        NaN         NaN       NaN        NaN  ...         NaN       NaN
#
#    SV_OUT_7A  SV_MEAN_7A  SV_IN_8A  SV_OUT_8A  SV_MEAN_8A  SV_IN_9A  \
# 0        NaN         NaN       NaN        NaN         NaN       NaN
# 1        NaN         NaN       NaN        NaN         NaN       NaN
# 2        NaN         NaN       NaN        NaN         NaN       NaN
# 3        NaN         NaN       NaN        NaN         NaN       NaN
# 4        NaN         NaN       NaN        NaN         NaN       NaN
#
#    SV_OUT_9A  SV_MEAN_9A
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN
#
# [5 rows x 41 columns]

# %%
df_SF['DATE'] = [datetime.date(i) for i in df_SF['TIMESTAMP']]
df_SF.head()
# Out:
#             TIMESTAMP  DOY  SV_IN_1A  SV_OUT_1A  SV_MEAN_1A  SV_IN_1B  \
# 0 2015-01-01 00:00:00    1       NaN        NaN         NaN       NaN
# 1 2015-01-01 00:15:00    1       NaN        NaN         NaN       NaN
# 2 2015-01-01 00:30:00    1       NaN        NaN         NaN       NaN
# 3 2015-01-01 00:45:00    1       NaN        NaN         NaN       NaN
# 4 2015-01-01 01:00:00    1       NaN        NaN         NaN       NaN
#
#    SV_OUT_1B  SV_MEAN_1B  SV_IN_2A  SV_OUT_2A  ...  SV_IN_7A  SV_OUT_7A  \
# 0        NaN         NaN       NaN        NaN  ...       NaN        NaN
# 1        NaN         NaN       NaN        NaN  ...       NaN        NaN
# 2        NaN         NaN       NaN        NaN  ...       NaN        NaN
# 3        NaN         NaN       NaN        NaN  ...       NaN        NaN
# 4        NaN         NaN       NaN        NaN  ...       NaN        NaN
#
#    SV_MEAN_7A  SV_IN_8A  SV_OUT_8A  SV_MEAN_8A  SV_IN_9A  SV_OUT_9A  \
# 0         NaN       NaN        NaN         NaN       NaN        NaN
# 1         NaN       NaN        NaN         NaN       NaN        NaN
# 2         NaN       NaN        NaN         NaN       NaN        NaN
# 3         NaN       NaN        NaN         NaN       NaN        NaN
# 4         NaN       NaN        NaN         NaN       NaN        NaN
#
#    SV_MEAN_9A        DATE
# 0         NaN  2015-01-01
# 1         NaN  2015-01-01
# 2         NaN  2015-01-01
# 3         NaN  2015-01-01
# 4         NaN  2015-01-01
#
# [5 rows x 42 columns]

# %%
df_SF_grouped = df_SF.groupby(['DATE'],as_index = False)
df_SF_dailymax = df_SF_grouped.max()
df_SF_dailymax.head()
# Out:
#          DATE           TIMESTAMP  DOY  SV_IN_1A  SV_OUT_1A  SV_MEAN_1A  \
# 0  2015-01-01 2015-01-01 23:45:00    1       NaN        NaN         NaN
# 1  2015-01-02 2015-01-02 23:45:00    2       NaN        NaN         NaN
# 2  2015-01-03 2015-01-03 23:45:00    3       NaN        NaN         NaN
# 3  2015-01-04 2015-01-04 23:45:00    4       NaN        NaN         NaN
# 4  2015-01-05 2015-01-05 23:45:00    5       NaN        NaN         NaN
#
#    SV_IN_1B  SV_OUT_1B  SV_MEAN_1B  SV_IN_2A  ...  SV_MEAN_6A  SV_IN_7A  \
# 0       NaN        NaN         NaN       NaN  ...         NaN       NaN
# 1       NaN        NaN         NaN       NaN  ...         NaN       NaN
# 2       NaN        NaN         NaN       NaN  ...         NaN       NaN
# 3       NaN        NaN         NaN       NaN  ...         NaN       NaN
# 4       NaN        NaN         NaN       NaN  ...         NaN       NaN
#
#    SV_OUT_7A  SV_MEAN_7A  SV_IN_8A  SV_OUT_8A  SV_MEAN_8A  SV_IN_9A  \
# 0        NaN         NaN       NaN        NaN         NaN       NaN
# 1        NaN         NaN       NaN        NaN         NaN       NaN
# 2        NaN         NaN       NaN        NaN         NaN       NaN
# 3        NaN         NaN       NaN        NaN         NaN       NaN
# 4        NaN         NaN       NaN        NaN         NaN       NaN
#
#    SV_OUT_9A  SV_MEAN_9A
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN
#
# [5 rows x 42 columns]

# %%
df_SF_dailymax.to_pickle('df_SF_dailyMax.pkl')

# %%
df_SF_dailymax.plot(x='DATE',
                 y=['SV_MEAN_1A','SV_MEAN_2A','SV_MEAN_3A','SV_MEAN_4A',
                   'SV_MEAN_5A','SV_MEAN_6A','SV_MEAN_7A','SV_MEAN_8A','SV_MEAN_9A'],
                figsize = [10,6])
plt.legend(loc = 'center left',bbox_to_anchor=(1, 0.5))

# %%
df_SF_dailymax.plot(x='DATE',
                 y='SV_MEAN_2A',
                figsize = [8,5])
plt.legend(loc = 'center left',bbox_to_anchor=(1, 0.5))
